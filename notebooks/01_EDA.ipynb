# %% [markdown]
# # **Spotify Tracks Dataset: Exploratory Data Analysis (EDA)**

# %% [markdown]
# In this `notebook` we will go over the following:
# - Preliminary exploration of the data
# - Loading the data
# - Managing outliers, missing values and normalizing
# - Conducting an EDA

# %% [markdown]
# From the official Kaggle page we know the following:
# - Total observations: ≈114 000
# - Total features: 20 (excluding the observation index)
#
# The features are as follows:
# |Numerical Continuous|Numerical Discrete|Categorical Nominal|Categorical Ordinal|Binary|Textual|
# |---|---|---|---|---|---|
# | `duration_ms`<br>`danceability`<br>`energy`<br>`loudness`<br>`speechiness`<br>`acousticness`<br>`instrumentalness`<br>`liveness`<br>`valence`<br>`tempo`| `popularity`<br>`time_signature` | `track_genre`<br>`key` |  | `explicit`<br>`mode` | `track_id`<br>`artists`<br>`album_name`<br>`track_name` |

# %% [markdown]
# ![Feature descriptions (from the Kaggle page)](./aux/featureDescriptionsKaggle.png)

# %% [markdown]
# We will use numpy for vector operations, we will use pandas to load and represent tabular data and we will use matplotlib to represent data visually.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sys
sys.path.append('./aux')
import eda_aux as aux


# Aixo ho he tret del chat, serveix perque quan modifiquem eda_aux.py s'actualitzi al notebook automaticament :) (Pau)
# %load_ext autoreload
# %autoreload 2


print(f'cwd: {os.getcwd()}')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# cwd: /Users/prossell/Documents/Estudis UAB/Intel·ligència Artificial/1/2/Eng. Dades/DataEng-project/notebooks

# %%
# Here we load the CSV
data = pd.read_csv('../data/raw/dataset.csv')
nObs, nFeat = data.shape
print(f'Total observations: {nObs}\nTotal features: {nFeat}')
data.head()
# Out:
# Total observations: 114000
# Total features: 21
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# ...

# %%
# Now we will go over some descriptive statistics for the dataset and its features.
data.info()
data.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  str
#  2   artists           113999 non-null  str
#  3   album_name        113999 non-null  str
#  4   track_name        113999 non-null  str
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %% [markdown]
# The most notable fact we can deduce from the information obtained by pandas info and deduce is that there are almost no null values at all in the dataset, with the exception of the artists, album_name and track_name features which each have a singular null value. There is also a column (Unnnamed) which contains observation index values which, since we are using a pandas dataframe to represent the data (which already contains row indexes), we do not need.

# %%
# Next, it will be good to elaborate a box plot for the numerical features of the data, to better visualize the values obtained above
numericalFeatures = aux.features['numContinuous'] + aux.features['numDiscrete']
aux.elaborateBoxPlots(featureList=numericalFeatures, data=data) # La funcio la he creat apart al fitxer auxiliar .py (Pau)
plt.show()
